# %% [markdown]
# # Modelo Deep learning NER con bilstm y crf - clinicalEmb-300-skyp
# ## NewDataset Lung Cancer
#
# ### Definicion de Parametro e Hiperparametros del Modelo

# %%
import sys
sys.path.append('./libs')

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pandas as pd
import seaborn as sn
from itertools import islice

from tabulate import tabulate
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report as eskclarep
from seqeval.metrics import precision_score, recall_score, f1_score, accuracy_score
from seqeval.metrics import classification_report as seqclarep
from sklearn.preprocessing import LabelBinarizer
from itertools import chain
from sklearn.model_selection import KFold

from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Concatenate, Lambda, Input, LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, InputLayer, Activation, Flatten, Masking
from tensorflow.keras.optimizers import Adam, schedules

from tf2crf import CRF as crf6
from mwrapper import ModelWithCRFLoss, ModelWithCRFLossDSCLoss
from utils import build_matrix_embeddings as bme, plot_model_performance, logits_to_tokens, report_to_df2

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard

from IPython.core.display import display, HTML

import datetime, os
import random

# %%
SEED = 42
os.environ['PYTHONHASHSEED']=str(SEED)
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # TF 2.1+
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

MODEL         = 'new-clinical-base_model_epoch_60'
logs_base_dir = "./logs"
log_dir       = logs_base_dir + "/" + MODEL
save_base_dir = './model-save'
save_dir      = save_base_dir + "/" + MODEL

os.makedirs(logs_base_dir, exist_ok=True)
os.makedirs(log_dir,       exist_ok=True)
os.makedirs(save_base_dir, exist_ok=True)
os.makedirs(save_dir,      exist_ok=True)

#%load_ext tensorboard

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
# ****** DEFINICION DE PARAMETROS *********
NUM_WORDS       = 13705 + 2
LEN_SENTS       = 306
NUM_TAGS        = 37 + 2


# ****** DEFINICION DE HIPERPARAMETROS *********
_EPOCHS         = 50
EMBED_DIM       = 300
_DROPOUT        = 0.5
_BACH_SIZE      = 512 + (256+128)
_LEARN_RATE     = 5e-3
NUM_FOLDS       = 10
VAL_SPLIT       = 0.2

prime_data_fold = []
total_data_fold = []

# %% [markdown]
# ## Se cargan los datos de Entrenamiento

# %%
total_sentences = []

with open("./vectors/sentences_train.txt", "rb") as fp:
    total_sentences = pickle.load(fp)
    
    
## ********** Oraciones ********** ##
word2idx = np.load('./vectors/word2index.npy', allow_pickle=True).item()
idx2word = {v: k for k, v in word2idx.items()}

idx2tag  = np.load('./vectors/index2tag.npy', allow_pickle=True).item()

x_inputs = np.load('./vectors/X_train.npy')

print(x_inputs.shape)

## ********** Salidas ********** ##
y_output = np.load('./vectors/y_train.npy')


print(y_output.shape)
# Out:
# (18900, 306)
# (18900, 306, 39)

# %%
#print(type(y_train))
#print(y_train[0])
#(11773, 310)
#(2790, 310)
#(3480, 310)
print(total_sentences[0])
# Out:
# [('Motivo', 'O'), ('de', 'O'), ('Ingreso', 'O'), (':', 'O'), ('Cefalea', 'O'), (',', 'O'), ('mal', 'O'), ('control', 'O'), ('del', 'O'), ('dolor', 'O'), ('.', 'O')]

# %% [markdown]
# ## Pruebas de carga de datos

# %%
#print('**** Diccionario de palabras: ****\n')
#for key, value in feature_lemma_to_idx.items():
#    if value == 10:
#        break
#    else:
#        print(key, ' : ', value)
        
#print(X_train[0], "\n")
#print(len(X_train))

#print(y_train[0])
#print(len(y_train))
#print(len(y_test))
#print(len(y_dev))

# %% [markdown]
# ### Se carga el embedding

# %%
file = '../oswaldo-nubes/embedding/Biomed/clinical/cased/skipgram/d300/clinic_es.vec'
embedding_matrix = bme(file, NUM_WORDS, EMBED_DIM, word2idx)
# Out:
# Cargando archivo...
# 0it [00:00, ?it/s]
# Encontrados 133674 Vectores de pabras.
#   0%|          | 0/14487 [00:00<?, ?it/s]
# Convertidos: 10475 Tokens | Perdidos: 3736 Tokens

# %% [markdown]
# ## Definición del Modelo

# %%
def get_model(print_sumary=0):
    strategy = tf.distribute.MirroredStrategy()

    with strategy.scope():
        loss      = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        optimizer = keras.optimizers.Adam(lr=_LEARN_RATE)
        
        # Input Layer
        input1 = Input(shape=(LEN_SENTS,), dtype='int32')

        # Embedding Layer
        sentences = Embedding(NUM_WORDS,
                              EMBED_DIM,
                              input_length=LEN_SENTS,
                              weights=[embedding_matrix],
                              trainable=False,
                              mask_zero=False)(input1)

        drp_sentences = Dropout(_DROPOUT, name='dropout_sentences')(sentences)

        # BI-LSTM Layer
        myModel = Bidirectional(LSTM(EMBED_DIM, 
                                     return_sequences=True
                                    ),
                                name='bilstm1')(drp_sentences)


        myModel  = Dropout(_DROPOUT, name='dropout_lstm')(myModel)
        myModel  = Dense(units=EMBED_DIM * 2, activation='relu')(myModel)
        myModel  = Dense(units=NUM_TAGS, activation='relu')(myModel)

        myModel  = Masking(mask_value=0.,input_shape=(LEN_SENTS, NUM_TAGS))(myModel)

        crf = crf6(units=NUM_TAGS, name="ner_crf")
        predictions = crf(myModel)

        base_model = Model(inputs=input1, outputs=predictions)
        model = ModelWithCRFLoss(base_model, sparse_target=True)

        #model.compile(optimizer='adam')
        model.compile(optimizer=optimizer, loss=loss)

    if print_sumary == 1:
        base_model.summary()
    
    return model

# %% [markdown]
# ## Entranamiento del modelo

# %%
kfold = KFold(n_splits=NUM_FOLDS, shuffle=True)

fold_no = 1
for train_index, test_index in kfold.split(x_inputs):
    
    model = get_model(fold_no)
    
    # Fit the best model
    history = model.fit([x_inputs[train_index]], y_output[train_index],
                        validation_split = VAL_SPLIT,
                        batch_size       = _BACH_SIZE,
                        epochs           = _EPOCHS,
                        verbose          = 2)
    
    ### se almacena el modelo
    
    
    ### Evaluamos el modelo y calculamos el valor de precision con respecto a los datos de prueba
    scores = model.evaluate([x_inputs[test_index]], y_output[test_index])
    print(f"{model.metrics_names[1]}: {scores[1] * 100}")
    
    
    ###  Procedemos a Graficar el comportamiento del Entrenamiento, tanto del conjunto  
    ### de entrenamiento  como el de validación con respecto a la cantidad de epocas
    plot_model_performance(
        train_loss     = history.history.get('loss', []),
        train_acc      = history.history.get('accuracy', []),
        train_val_loss = history.history.get('val_loss_val', []),
        train_val_acc  = history.history.get('val_val_accuracy', [])
    )
    
    ### Hacemos la prediccion sobre el conjunto de pruebas
    
    #print(idx2tag[6])
    prediction = model.predict([x_inputs[test_index]])
    
    y_pred = logits_to_tokens(prediction, idx2tag)
    #print(y_pred[0])
    
    ### Hallamos los valores de F1 score, recall, precision

    y_true = []
    for i, index in enumerate(test_index):
        oracion = total_sentences[index]
        row_sent = []

        for j, lista_palabras in enumerate(oracion):
            row_sent.append(lista_palabras[1])

        qekk = ['-PAD-'] * LEN_SENTS

        qekk[:len(row_sent)] = row_sent
        y_true.append(qekk)
    
  
    
    li1 = sum(y_true, [])
    li2 = sum(y_pred, [])

    results = pd.DataFrame(columns=['Expected', 'Predicted'])

    results['Expected'] = li1
    results['Predicted'] = li2
    
    #print('\nclassification_report:\n', seqclarep(y_true, y_pred))

    print("precision: {:.1%}".format(precision_score(y_true, y_pred)))
    print("   recall: {:.1%}".format(recall_score(y_true,    y_pred)))
    print(" accuracy: {:.1%}".format(accuracy_score(y_true,  y_pred)))
    print(" F1-score: {:.1%}".format(f1_score(y_true,        y_pred)))
    
    info = []

    info.append("precision: {:.1%}".format(precision_score(y_true, y_pred)))
    info.append("   recall: {:.1%}".format(recall_score(y_true,    y_pred)))
    info.append(" accuracy: {:.1%}".format(accuracy_score(y_true,  y_pred)))
    info.append(" F1-score: {:.1%}".format(f1_score(y_true,        y_pred)))

    prime_data_fold.append(info)
    
    ### Hallamos el calculo de cada una de las etiquetas por separado
    report = eskclarep(results['Expected'], results['Predicted'])
    #print('\nclassification_report:\n', report)

    data = {'y_Actual':    results['Expected'],
            'y_Predicted': results['Predicted']
            }

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'], margins = True)

    sn.heatmap(confusion_matrix, annot=True)

    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
    
    rep_kfl = report_to_df2(report, '-fol' + str(fold_no))
    
    total_data_fold.append(rep_kfl)
    
    print(rep_kfl)
    
    ######### ----- Codigo nuevo para salvar los array: y_true, y_pred ----------
    array_result = []
    array_result.append((y_true, y_pred))# Se usara para calcular NER Eval
    arrayNER = np.array(array_result)
    
    dirName= './NER-scoring-data/'
    fileName =  dirName + "fold-" + str(fold_no) + '.npy'
    np.save(fileName, arrayNER)
    
    #####---------------------------------------------------------------------
        
        
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 306)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 306, 300)          4112100
# _________________________________________________________________
# dropout_sentences (Dropout)  (None, 306, 300)          0
# _________________________________________________________________
# bilstm1 (Bidirectional)      (None, 306, 600)          1442400
# _________________________________________________________________
# dropout_lstm (Dropout)       (None, 306, 600)          0
# _________________________________________________________________
# dense (Dense)                (None, 306, 600)          360600
# _________________________________________________________________
# dense_1 (Dense)              (None, 306, 39)           23439
# _________________________________________________________________
# masking (Masking)            (None, 306, 39)           0
# _________________________________________________________________
# ner_crf (CRF)                ((None, 306), (None, 306, 3083
# =================================================================
# Total params: 5,941,622
# Trainable params: 1,829,520
# Non-trainable params: 4,112,102
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# 15/15 - 29s - loss: 445.5340 - accuracy: 0.7248 - val_loss_val: 35.1429 - val_val_accuracy: 0.9825
# Epoch 2/50
# 15/15 - 17s - loss: 26.5409 - accuracy: 0.9846 - val_loss_val: 23.9335 - val_val_accuracy: 0.9848
# Epoch 3/50
# 15/15 - 17s - loss: 21.1740 - accuracy: 0.9848 - val_loss_val: 20.9565 - val_val_accuracy: 0.9846
# Epoch 4/50
# 15/15 - 17s - loss: 19.0375 - accuracy: 0.9850 - val_loss_val: 19.2111 - val_val_accuracy: 0.9857
# Epoch 5/50
# 15/15 - 17s - loss: 17.2543 - accuracy: 0.9865 - val_loss_val: 17.4175 - val_val_accuracy: 0.9870
# Epoch 6/50
# 15/15 - 17s - loss: 15.4451 - accuracy: 0.9877 - val_loss_val: 15.6750 - val_val_accuracy: 0.9879
# Epoch 7/50
# 15/15 - 17s - loss: 13.6907 - accuracy: 0.9890 - val_loss_val: 14.0051 - val_val_accuracy: 0.9890
# Epoch 8/50
# 15/15 - 17s - loss: 12.1728 - accuracy: 0.9902 - val_loss_val: 12.6282 - val_val_accuracy: 0.9899
# Epoch 9/50
# 15/15 - 17s - loss: 10.9079 - accuracy: 0.9910 - val_loss_val: 11.5568 - val_val_accuracy: 0.9905
# Epoch 10/50
# 15/15 - 17s - loss: 9.9350 - accuracy: 0.9915 - val_loss_val: 10.4706 - val_val_accuracy: 0.9911
# Epoch 11/50
# 15/15 - 17s - loss: 9.0816 - accuracy: 0.9921 - val_loss_val: 9.6317 - val_val_accuracy: 0.9917
# Epoch 12/50
# 15/15 - 17s - loss: 8.2518 - accuracy: 0.9926 - val_loss_val: 8.9149 - val_val_accuracy: 0.9922
# Epoch 13/50
# 15/15 - 17s - loss: 7.5832 - accuracy: 0.9932 - val_loss_val: 8.1843 - val_val_accuracy: 0.9928
# Epoch 14/50
# 15/15 - 17s - loss: 6.9738 - accuracy: 0.9937 - val_loss_val: 7.5307 - val_val_accuracy: 0.9934
# Epoch 15/50
# 15/15 - 17s - loss: 6.4125 - accuracy: 0.9943 - val_loss_val: 6.9497 - val_val_accuracy: 0.9939
# Epoch 16/50
# 15/15 - 17s - loss: 5.8669 - accuracy: 0.9947 - val_loss_val: 6.5277 - val_val_accuracy: 0.9942
# Epoch 17/50
# 15/15 - 17s - loss: 5.5012 - accuracy: 0.9951 - val_loss_val: 6.1683 - val_val_accuracy: 0.9945
# Epoch 18/50
# 15/15 - 17s - loss: 5.1317 - accuracy: 0.9954 - val_loss_val: 5.7996 - val_val_accuracy: 0.9948
# Epoch 19/50
# 15/15 - 17s - loss: 4.8458 - accuracy: 0.9956 - val_loss_val: 5.5405 - val_val_accuracy: 0.9950
# Epoch 20/50
# 15/15 - 17s - loss: 4.5639 - accuracy: 0.9958 - val_loss_val: 5.2815 - val_val_accuracy: 0.9952
# Epoch 21/50
# 15/15 - 17s - loss: 4.3591 - accuracy: 0.9960 - val_loss_val: 5.0482 - val_val_accuracy: 0.9953
# Epoch 22/50
# 15/15 - 17s - loss: 4.1987 - accuracy: 0.9962 - val_loss_val: 4.8293 - val_val_accuracy: 0.9956
# Epoch 23/50
# 15/15 - 17s - loss: 3.9772 - accuracy: 0.9964 - val_loss_val: 4.6465 - val_val_accuracy: 0.9957
# Epoch 24/50
# 15/15 - 17s - loss: 3.8095 - accuracy: 0.9965 - val_loss_val: 4.4851 - val_val_accuracy: 0.9958
# Epoch 25/50
# 15/15 - 17s - loss: 3.6734 - accuracy: 0.9966 - val_loss_val: 4.3138 - val_val_accuracy: 0.9959
# Epoch 26/50
# 15/15 - 17s - loss: 3.5353 - accuracy: 0.9967 - val_loss_val: 4.1795 - val_val_accuracy: 0.9960
# Epoch 27/50
# 15/15 - 17s - loss: 3.4212 - accuracy: 0.9968 - val_loss_val: 4.0464 - val_val_accuracy: 0.9962
# Epoch 28/50
# 15/15 - 17s - loss: 3.3011 - accuracy: 0.9969 - val_loss_val: 3.9589 - val_val_accuracy: 0.9962
# Epoch 29/50
# 15/15 - 17s - loss: 3.1886 - accuracy: 0.9970 - val_loss_val: 3.8966 - val_val_accuracy: 0.9963
# Epoch 30/50
# 15/15 - 17s - loss: 3.1129 - accuracy: 0.9971 - val_loss_val: 3.6980 - val_val_accuracy: 0.9964
# Epoch 31/50
# 15/15 - 17s - loss: 3.0007 - accuracy: 0.9972 - val_loss_val: 3.7164 - val_val_accuracy: 0.9964
# Epoch 32/50
# 15/15 - 17s - loss: 2.9189 - accuracy: 0.9972 - val_loss_val: 3.5965 - val_val_accuracy: 0.9966
# Epoch 33/50
# 15/15 - 17s - loss: 2.8506 - accuracy: 0.9973 - val_loss_val: 3.5647 - val_val_accuracy: 0.9965
# Epoch 34/50
# 15/15 - 17s - loss: 2.7946 - accuracy: 0.9973 - val_loss_val: 3.3615 - val_val_accuracy: 0.9967
# Epoch 35/50
# 15/15 - 17s - loss: 2.6979 - accuracy: 0.9974 - val_loss_val: 3.4171 - val_val_accuracy: 0.9966
# Epoch 36/50
# 15/15 - 17s - loss: 2.6389 - accuracy: 0.9974 - val_loss_val: 3.2931 - val_val_accuracy: 0.9967
# Epoch 37/50
# 15/15 - 17s - loss: 2.5667 - accuracy: 0.9975 - val_loss_val: 3.2056 - val_val_accuracy: 0.9969
# Epoch 38/50
# 15/15 - 17s - loss: 2.5298 - accuracy: 0.9975 - val_loss_val: 3.1740 - val_val_accuracy: 0.9968
# Epoch 39/50
# 15/15 - 17s - loss: 2.4690 - accuracy: 0.9976 - val_loss_val: 3.1350 - val_val_accuracy: 0.9968
# Epoch 40/50
# 15/15 - 17s - loss: 2.4058 - accuracy: 0.9976 - val_loss_val: 3.0490 - val_val_accuracy: 0.9969
# Epoch 41/50
# 15/15 - 17s - loss: 2.3416 - accuracy: 0.9977 - val_loss_val: 3.0260 - val_val_accuracy: 0.9970
# Epoch 42/50
# 15/15 - 17s - loss: 2.2867 - accuracy: 0.9977 - val_loss_val: 2.9139 - val_val_accuracy: 0.9970
# Epoch 43/50
# 15/15 - 17s - loss: 2.2480 - accuracy: 0.9978 - val_loss_val: 2.9901 - val_val_accuracy: 0.9970
# Epoch 44/50
# 15/15 - 17s - loss: 2.2367 - accuracy: 0.9978 - val_loss_val: 2.8653 - val_val_accuracy: 0.9971
# Epoch 45/50
# 15/15 - 17s - loss: 2.1967 - accuracy: 0.9978 - val_loss_val: 2.8124 - val_val_accuracy: 0.9972
# Epoch 46/50
# 15/15 - 17s - loss: 2.1477 - accuracy: 0.9979 - val_loss_val: 2.7843 - val_val_accuracy: 0.9971
# Epoch 47/50
# 15/15 - 17s - loss: 2.1107 - accuracy: 0.9978 - val_loss_val: 2.7845 - val_val_accuracy: 0.9972
# Epoch 48/50
# 15/15 - 17s - loss: 2.0820 - accuracy: 0.9979 - val_loss_val: 2.7498 - val_val_accuracy: 0.9972
# Epoch 49/50
# 15/15 - 17s - loss: 2.0332 - accuracy: 0.9979 - val_loss_val: 2.7070 - val_val_accuracy: 0.9972
# Epoch 50/50
# 15/15 - 17s - loss: 1.9838 - accuracy: 0.9980 - val_loss_val: 2.6441 - val_val_accuracy: 0.9973
# 85/85 [==============================] - 13s 149ms/step - loss_val: 2.1934 - val_accuracy: 0.9977
# accuracy: 99.75562691688538
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 92.6%
#    recall: 91.9%
#  accuracy: 99.8%
#  F1-score: 92.3%
#             Class Name precision recall f1-score support  model
# 0                -fol1      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  784259  -fol1
# 2     B-CANCER_CONCEPT      0.96   0.94     0.95     716  -fol1
# 3       B-CHEMOTHERAPY      0.99   0.96     0.98     169  -fol1
# 4   B-CLINICAL_SERVICE      0.88   0.92     0.90     106  -fol1
# 5        B-COMORBIDITY      0.92   0.85     0.89     502  -fol1
# 6               B-DATE      0.93   0.92     0.92     815  -fol1
# 7               B-DRUG      0.98   0.95     0.96     920  -fol1
# 8             B-FAMILY      0.97   0.99     0.98     144  -fol1
# 9               B-FREQ      0.92   0.95     0.94     304  -fol1
# 10     B-IMPLICIT_DATE      0.79   0.89     0.84     103  -fol1
# 11            B-METRIC      0.96   0.95     0.96    1576  -fol1
# 12          B-MUTATION      0.99   1.00     1.00     242  -fol1
# 13   B-MUTATION_STATUS      0.95   0.98     0.96     193  -fol1
# 14   B-OCURRENCE_EVENT      0.92   0.96     0.94     530  -fol1
# 15          B-QUANTITY      0.98   0.95     0.96    1896  -fol1
# 16      B-RADIOTHERAPY      0.95   0.95     0.95     111  -fol1
# 17     B-SMOKER_STATUS      0.98   0.92     0.95     122  -fol1
# 18             B-STAGE      0.96   0.93     0.95     178  -fol1
# 19           B-SURGERY      0.90   0.86     0.88     138  -fol1
# 20               B-TNM      0.83   0.89     0.86     195  -fol1
# 21    I-CANCER_CONCEPT      0.93   0.96     0.94    1485  -fol1
# 22  I-CLINICAL_SERVICE      0.91   0.87     0.89      69  -fol1
# 23       I-COMORBIDITY      0.74   0.70     0.72     140  -fol1
# 24              I-DATE      0.98   0.98     0.98     568  -fol1
# 25              I-DRUG      1.00   0.93     0.96      70  -fol1
# 26            I-FAMILY      0.98   0.96     0.97      47  -fol1
# 27              I-FREQ      0.93   0.93     0.93     245  -fol1
# 28     I-IMPLICIT_DATE      0.83   0.96     0.89     214  -fol1
# 29            I-METRIC      0.95   0.93     0.94     375  -fol1
# 30          I-MUTATION      1.00   0.95     0.97      37  -fol1
# 31   I-MUTATION_STATUS      0.93   0.99     0.96     153  -fol1
# 32   I-OCURRENCE_EVENT      0.86   0.84     0.85     225  -fol1
# 33          I-QUANTITY      0.64   0.83     0.72      59  -fol1
# 34     I-SMOKER_STATUS      1.00   0.94     0.97      35  -fol1
# 35             I-STAGE      0.93   0.96     0.95     165  -fol1
# 36           I-SURGERY      0.81   0.83     0.82     160  -fol1
# 37               I-TNM      0.90   0.87     0.89     163  -fol1
# 38                   O      0.98   0.98     0.98   28771  -fol1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# 15/15 - 27s - loss: 273.2601 - accuracy: 0.7626 - val_loss_val: 42.6483 - val_val_accuracy: 0.9503
# Epoch 2/50
# 15/15 - 17s - loss: 30.8688 - accuracy: 0.9758 - val_loss_val: 25.8752 - val_val_accuracy: 0.9841
# Epoch 3/50
# 15/15 - 17s - loss: 22.9189 - accuracy: 0.9845 - val_loss_val: 22.7943 - val_val_accuracy: 0.9843
# Epoch 4/50
# 15/15 - 17s - loss: 20.6877 - accuracy: 0.9846 - val_loss_val: 21.0979 - val_val_accuracy: 0.9844
# Epoch 5/50
# 15/15 - 17s - loss: 19.3954 - accuracy: 0.9847 - val_loss_val: 19.9988 - val_val_accuracy: 0.9845
# Epoch 6/50
# 15/15 - 17s - loss: 18.3160 - accuracy: 0.9848 - val_loss_val: 18.9812 - val_val_accuracy: 0.9847
# Epoch 7/50
# 15/15 - 17s - loss: 17.1787 - accuracy: 0.9854 - val_loss_val: 17.8513 - val_val_accuracy: 0.9857
# Epoch 8/50
# 15/15 - 17s - loss: 15.9756 - accuracy: 0.9867 - val_loss_val: 16.5673 - val_val_accuracy: 0.9873
# Epoch 9/50
# 15/15 - 17s - loss: 14.6283 - accuracy: 0.9885 - val_loss_val: 15.0694 - val_val_accuracy: 0.9885
# Epoch 10/50
# 15/15 - 17s - loss: 13.0008 - accuracy: 0.9895 - val_loss_val: 13.4264 - val_val_accuracy: 0.9891
# Epoch 11/50
# 15/15 - 17s - loss: 11.6317 - accuracy: 0.9900 - val_loss_val: 12.1750 - val_val_accuracy: 0.9895
# Epoch 12/50
# 15/15 - 17s - loss: 10.3154 - accuracy: 0.9906 - val_loss_val: 10.8519 - val_val_accuracy: 0.9901
# Epoch 13/50
# 15/15 - 17s - loss: 9.0829 - accuracy: 0.9917 - val_loss_val: 9.6407 - val_val_accuracy: 0.9916
# Epoch 14/50
# 15/15 - 17s - loss: 8.0505 - accuracy: 0.9929 - val_loss_val: 8.5976 - val_val_accuracy: 0.9926
# Epoch 15/50
# 15/15 - 17s - loss: 7.0750 - accuracy: 0.9937 - val_loss_val: 7.7133 - val_val_accuracy: 0.9931
# Epoch 16/50
# 15/15 - 17s - loss: 6.4299 - accuracy: 0.9942 - val_loss_val: 7.0359 - val_val_accuracy: 0.9935
# Epoch 17/50
# 15/15 - 17s - loss: 5.8115 - accuracy: 0.9946 - val_loss_val: 6.4148 - val_val_accuracy: 0.9940
# Epoch 18/50
# 15/15 - 17s - loss: 5.4435 - accuracy: 0.9950 - val_loss_val: 6.1100 - val_val_accuracy: 0.9943
# Epoch 19/50
# 15/15 - 17s - loss: 5.0002 - accuracy: 0.9954 - val_loss_val: 5.6126 - val_val_accuracy: 0.9947
# Epoch 20/50
# 15/15 - 17s - loss: 4.6117 - accuracy: 0.9957 - val_loss_val: 5.3516 - val_val_accuracy: 0.9949
# Epoch 21/50
# 15/15 - 17s - loss: 4.3311 - accuracy: 0.9959 - val_loss_val: 4.9206 - val_val_accuracy: 0.9953
# Epoch 22/50
# 15/15 - 17s - loss: 4.1523 - accuracy: 0.9961 - val_loss_val: 4.6500 - val_val_accuracy: 0.9955
# Epoch 23/50
# 15/15 - 17s - loss: 3.8945 - accuracy: 0.9963 - val_loss_val: 4.4729 - val_val_accuracy: 0.9957
# Epoch 24/50
# 15/15 - 17s - loss: 3.7381 - accuracy: 0.9964 - val_loss_val: 4.2267 - val_val_accuracy: 0.9958
# Epoch 25/50
# 15/15 - 17s - loss: 3.5873 - accuracy: 0.9966 - val_loss_val: 4.2249 - val_val_accuracy: 0.9959
# Epoch 26/50
# 15/15 - 17s - loss: 3.4324 - accuracy: 0.9967 - val_loss_val: 4.0277 - val_val_accuracy: 0.9960
# Epoch 27/50
# 15/15 - 17s - loss: 3.3088 - accuracy: 0.9968 - val_loss_val: 3.8426 - val_val_accuracy: 0.9961
# Epoch 28/50
# 15/15 - 17s - loss: 3.2350 - accuracy: 0.9968 - val_loss_val: 3.8251 - val_val_accuracy: 0.9963
# Epoch 29/50
# 15/15 - 17s - loss: 3.1150 - accuracy: 0.9970 - val_loss_val: 3.6874 - val_val_accuracy: 0.9963
# Epoch 30/50
# 15/15 - 17s - loss: 3.0139 - accuracy: 0.9970 - val_loss_val: 3.5553 - val_val_accuracy: 0.9964
# Epoch 31/50
# 15/15 - 17s - loss: 3.0043 - accuracy: 0.9971 - val_loss_val: 3.5065 - val_val_accuracy: 0.9964
# Epoch 32/50
# 15/15 - 17s - loss: 2.8625 - accuracy: 0.9972 - val_loss_val: 3.4582 - val_val_accuracy: 0.9965
# Epoch 33/50
# 15/15 - 17s - loss: 2.8032 - accuracy: 0.9972 - val_loss_val: 3.3588 - val_val_accuracy: 0.9966
# Epoch 34/50
# 15/15 - 17s - loss: 2.7849 - accuracy: 0.9973 - val_loss_val: 3.3199 - val_val_accuracy: 0.9967
# Epoch 35/50
# 15/15 - 17s - loss: 2.6414 - accuracy: 0.9974 - val_loss_val: 3.1667 - val_val_accuracy: 0.9967
# Epoch 36/50
# 15/15 - 17s - loss: 2.6288 - accuracy: 0.9974 - val_loss_val: 3.2886 - val_val_accuracy: 0.9967
# Epoch 37/50
# 15/15 - 17s - loss: 2.5501 - accuracy: 0.9975 - val_loss_val: 3.1165 - val_val_accuracy: 0.9968
# Epoch 38/50
# 15/15 - 17s - loss: 2.4891 - accuracy: 0.9975 - val_loss_val: 3.1155 - val_val_accuracy: 0.9967
# Epoch 39/50
# 15/15 - 17s - loss: 2.4899 - accuracy: 0.9975 - val_loss_val: 3.0523 - val_val_accuracy: 0.9968
# Epoch 40/50
# 15/15 - 17s - loss: 2.3896 - accuracy: 0.9976 - val_loss_val: 2.9598 - val_val_accuracy: 0.9969
# Epoch 41/50
# 15/15 - 17s - loss: 2.3917 - accuracy: 0.9976 - val_loss_val: 2.9583 - val_val_accuracy: 0.9968
# Epoch 42/50
# 15/15 - 17s - loss: 2.3464 - accuracy: 0.9976 - val_loss_val: 2.8709 - val_val_accuracy: 0.9969
# Epoch 43/50
# 15/15 - 17s - loss: 2.3008 - accuracy: 0.9977 - val_loss_val: 2.8884 - val_val_accuracy: 0.9969
# Epoch 44/50
# 15/15 - 17s - loss: 2.2634 - accuracy: 0.9977 - val_loss_val: 2.9158 - val_val_accuracy: 0.9969
# Epoch 45/50
# 15/15 - 17s - loss: 2.2305 - accuracy: 0.9977 - val_loss_val: 2.8313 - val_val_accuracy: 0.9970
# Epoch 46/50
# 15/15 - 17s - loss: 2.1878 - accuracy: 0.9977 - val_loss_val: 2.7432 - val_val_accuracy: 0.9971
# Epoch 47/50
# 15/15 - 17s - loss: 2.1290 - accuracy: 0.9978 - val_loss_val: 2.8253 - val_val_accuracy: 0.9971
# Epoch 48/50
# 15/15 - 17s - loss: 2.1241 - accuracy: 0.9978 - val_loss_val: 2.8059 - val_val_accuracy: 0.9971
# Epoch 49/50
# 15/15 - 17s - loss: 2.0758 - accuracy: 0.9978 - val_loss_val: 2.7809 - val_val_accuracy: 0.9971
# Epoch 50/50
# 15/15 - 17s - loss: 2.0689 - accuracy: 0.9979 - val_loss_val: 2.6138 - val_val_accuracy: 0.9971
# 85/85 [==============================] - 14s 160ms/step - loss_val: 2.1695 - val_accuracy: 0.9978
# accuracy: 99.77015256881714
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 92.3%
#    recall: 92.7%
#  accuracy: 99.8%
#  F1-score: 92.5%
#             Class Name precision recall f1-score support  model
# 0                -fol2      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  786061  -fol2
# 2     B-CANCER_CONCEPT      0.94   0.93     0.94     654  -fol2
# 3       B-CHEMOTHERAPY      0.98   0.97     0.98     155  -fol2
# 4   B-CLINICAL_SERVICE      0.96   0.91     0.93     134  -fol2
# 5        B-COMORBIDITY      0.93   0.89     0.91     493  -fol2
# 6               B-DATE      0.92   0.93     0.92     768  -fol2
# 7               B-DRUG      0.95   0.97     0.96     905  -fol2
# 8             B-FAMILY      0.95   0.95     0.95     109  -fol2
# 9               B-FREQ      0.93   0.94     0.93     313  -fol2
# 10     B-IMPLICIT_DATE      0.81   0.90     0.85     109  -fol2
# 11            B-METRIC      0.95   0.97     0.96    1470  -fol2
# 12          B-MUTATION      0.99   0.96     0.98     227  -fol2
# 13   B-MUTATION_STATUS      0.96   0.94     0.95     172  -fol2
# 14   B-OCURRENCE_EVENT      0.93   0.94     0.94     469  -fol2
# 15          B-QUANTITY      0.96   0.95     0.96    1761  -fol2
# 16      B-RADIOTHERAPY      0.99   0.92     0.95     101  -fol2
# 17     B-SMOKER_STATUS      0.95   0.87     0.91     118  -fol2
# 18             B-STAGE      0.95   0.99     0.97     164  -fol2
# 19           B-SURGERY      0.90   0.85     0.88     136  -fol2
# 20               B-TNM      0.91   0.91     0.91     197  -fol2
# 21    I-CANCER_CONCEPT      0.92   0.94     0.93    1244  -fol2
# 22  I-CLINICAL_SERVICE      0.96   0.88     0.92      52  -fol2
# 23       I-COMORBIDITY      0.68   0.86     0.76     102  -fol2
# 24              I-DATE      0.98   0.99     0.98     498  -fol2
# 25              I-DRUG      0.96   0.87     0.91      84  -fol2
# 26            I-FAMILY      0.92   0.97     0.94      34  -fol2
# 27              I-FREQ      0.93   0.96     0.94     221  -fol2
# 28     I-IMPLICIT_DATE      0.89   0.95     0.92     195  -fol2
# 29            I-METRIC      0.92   0.99     0.95     257  -fol2
# 30          I-MUTATION      1.00   0.85     0.92      27  -fol2
# 31   I-MUTATION_STATUS      0.92   0.99     0.95     134  -fol2
# 32   I-OCURRENCE_EVENT      0.88   0.85     0.87     186  -fol2
# 33          I-QUANTITY      0.63   0.47     0.54      89  -fol2
# 34     I-SMOKER_STATUS      1.00   0.96     0.98      48  -fol2
# 35             I-STAGE      0.99   0.98     0.99     153  -fol2
# 36           I-SURGERY      0.83   0.78     0.81     155  -fol2
# 37               I-TNM      0.95   0.95     0.95     128  -fol2
# 38                   O      0.98   0.98     0.98   28077  -fol2
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# 15/15 - 27s - loss: 220.7439 - accuracy: 0.8616 - val_loss_val: 25.9834 - val_val_accuracy: 0.9831
# Epoch 2/50
# 15/15 - 17s - loss: 21.5207 - accuracy: 0.9846 - val_loss_val: 20.5446 - val_val_accuracy: 0.9848
# Epoch 3/50
# 15/15 - 17s - loss: 17.6732 - accuracy: 0.9860 - val_loss_val: 17.4752 - val_val_accuracy: 0.9865
# Epoch 4/50
# 15/15 - 17s - loss: 14.8529 - accuracy: 0.9876 - val_loss_val: 14.5878 - val_val_accuracy: 0.9881
# Epoch 5/50
# 15/15 - 17s - loss: 12.0927 - accuracy: 0.9898 - val_loss_val: 12.0977 - val_val_accuracy: 0.9898
# Epoch 6/50
# 15/15 - 17s - loss: 9.8046 - accuracy: 0.9915 - val_loss_val: 9.9064 - val_val_accuracy: 0.9915
# Epoch 7/50
# 15/15 - 17s - loss: 8.0000 - accuracy: 0.9930 - val_loss_val: 8.2982 - val_val_accuracy: 0.9929
# Epoch 8/50
# 15/15 - 17s - loss: 6.6696 - accuracy: 0.9941 - val_loss_val: 7.0882 - val_val_accuracy: 0.9937
# Epoch 9/50
# 15/15 - 17s - loss: 5.7008 - accuracy: 0.9949 - val_loss_val: 6.2153 - val_val_accuracy: 0.9943
# Epoch 10/50
# 15/15 - 17s - loss: 5.0192 - accuracy: 0.9954 - val_loss_val: 5.5941 - val_val_accuracy: 0.9948
# Epoch 11/50
# 15/15 - 17s - loss: 4.5252 - accuracy: 0.9958 - val_loss_val: 5.0481 - val_val_accuracy: 0.9953
# Epoch 12/50
# 15/15 - 17s - loss: 4.1126 - accuracy: 0.9962 - val_loss_val: 4.9658 - val_val_accuracy: 0.9953
# Epoch 13/50
# 15/15 - 17s - loss: 3.8698 - accuracy: 0.9963 - val_loss_val: 4.4202 - val_val_accuracy: 0.9958
# Epoch 14/50
# 15/15 - 17s - loss: 3.5596 - accuracy: 0.9966 - val_loss_val: 4.2178 - val_val_accuracy: 0.9959
# Epoch 15/50
# 15/15 - 17s - loss: 3.3282 - accuracy: 0.9968 - val_loss_val: 3.8788 - val_val_accuracy: 0.9961
# Epoch 16/50
# 15/15 - 17s - loss: 3.1764 - accuracy: 0.9970 - val_loss_val: 3.8349 - val_val_accuracy: 0.9962
# Epoch 17/50
# 15/15 - 17s - loss: 2.9875 - accuracy: 0.9971 - val_loss_val: 3.6915 - val_val_accuracy: 0.9964
# Epoch 18/50
# 15/15 - 17s - loss: 2.8657 - accuracy: 0.9972 - val_loss_val: 3.4145 - val_val_accuracy: 0.9966
# Epoch 19/50
# 15/15 - 17s - loss: 2.7405 - accuracy: 0.9973 - val_loss_val: 3.3632 - val_val_accuracy: 0.9966
# Epoch 20/50
# 15/15 - 17s - loss: 2.6395 - accuracy: 0.9974 - val_loss_val: 3.3354 - val_val_accuracy: 0.9967
# Epoch 21/50
# 15/15 - 17s - loss: 2.5458 - accuracy: 0.9975 - val_loss_val: 3.1368 - val_val_accuracy: 0.9969
# Epoch 22/50
# 15/15 - 17s - loss: 2.4999 - accuracy: 0.9975 - val_loss_val: 3.1651 - val_val_accuracy: 0.9969
# Epoch 23/50
# 15/15 - 17s - loss: 2.3606 - accuracy: 0.9977 - val_loss_val: 3.0530 - val_val_accuracy: 0.9969
# Epoch 24/50
# 15/15 - 17s - loss: 2.3007 - accuracy: 0.9977 - val_loss_val: 2.9895 - val_val_accuracy: 0.9970
# Epoch 25/50
# 15/15 - 17s - loss: 2.2256 - accuracy: 0.9978 - val_loss_val: 2.9283 - val_val_accuracy: 0.9970
# Epoch 26/50
# 15/15 - 17s - loss: 2.1750 - accuracy: 0.9978 - val_loss_val: 2.9998 - val_val_accuracy: 0.9969
# Epoch 27/50
# 15/15 - 17s - loss: 2.1437 - accuracy: 0.9978 - val_loss_val: 2.8600 - val_val_accuracy: 0.9971
# Epoch 28/50
# 15/15 - 17s - loss: 2.0582 - accuracy: 0.9979 - val_loss_val: 2.7180 - val_val_accuracy: 0.9972
# Epoch 29/50
# 15/15 - 17s - loss: 1.9940 - accuracy: 0.9980 - val_loss_val: 2.6951 - val_val_accuracy: 0.9972
# Epoch 30/50
# 15/15 - 17s - loss: 1.9427 - accuracy: 0.9980 - val_loss_val: 2.6636 - val_val_accuracy: 0.9973
# Epoch 31/50
# 15/15 - 17s - loss: 1.8905 - accuracy: 0.9981 - val_loss_val: 2.6455 - val_val_accuracy: 0.9973
# Epoch 32/50
# 15/15 - 17s - loss: 1.8567 - accuracy: 0.9981 - val_loss_val: 2.6095 - val_val_accuracy: 0.9973
# Epoch 33/50
# 15/15 - 17s - loss: 1.8143 - accuracy: 0.9981 - val_loss_val: 2.5635 - val_val_accuracy: 0.9973
# Epoch 34/50
# 15/15 - 17s - loss: 1.7604 - accuracy: 0.9982 - val_loss_val: 2.5177 - val_val_accuracy: 0.9974
# Epoch 35/50
# 15/15 - 17s - loss: 1.7526 - accuracy: 0.9982 - val_loss_val: 2.4769 - val_val_accuracy: 0.9974
# Epoch 36/50
# 15/15 - 17s - loss: 1.7245 - accuracy: 0.9982 - val_loss_val: 2.4926 - val_val_accuracy: 0.9975
# Epoch 37/50
# 15/15 - 17s - loss: 1.6652 - accuracy: 0.9983 - val_loss_val: 2.4855 - val_val_accuracy: 0.9975
# Epoch 38/50
# 15/15 - 17s - loss: 1.6249 - accuracy: 0.9983 - val_loss_val: 2.4073 - val_val_accuracy: 0.9975
# Epoch 39/50
# 15/15 - 17s - loss: 1.5752 - accuracy: 0.9983 - val_loss_val: 2.4285 - val_val_accuracy: 0.9976
# Epoch 40/50
# 15/15 - 17s - loss: 1.5756 - accuracy: 0.9983 - val_loss_val: 2.3637 - val_val_accuracy: 0.9975
# Epoch 41/50
# 15/15 - 17s - loss: 1.5347 - accuracy: 0.9984 - val_loss_val: 2.3394 - val_val_accuracy: 0.9976
# Epoch 42/50
# 15/15 - 17s - loss: 1.5085 - accuracy: 0.9984 - val_loss_val: 2.3281 - val_val_accuracy: 0.9977
# Epoch 43/50
# 15/15 - 17s - loss: 1.5105 - accuracy: 0.9984 - val_loss_val: 2.3277 - val_val_accuracy: 0.9976
# Epoch 44/50
# 15/15 - 17s - loss: 1.4564 - accuracy: 0.9984 - val_loss_val: 2.3338 - val_val_accuracy: 0.9977
# Epoch 45/50
# 15/15 - 17s - loss: 1.4183 - accuracy: 0.9985 - val_loss_val: 2.2826 - val_val_accuracy: 0.9976
# Epoch 46/50
# 15/15 - 17s - loss: 1.4247 - accuracy: 0.9985 - val_loss_val: 2.2502 - val_val_accuracy: 0.9977
# Epoch 47/50
# 15/15 - 17s - loss: 1.3826 - accuracy: 0.9985 - val_loss_val: 2.2665 - val_val_accuracy: 0.9976
# Epoch 48/50
# 15/15 - 17s - loss: 1.4254 - accuracy: 0.9985 - val_loss_val: 2.1424 - val_val_accuracy: 0.9977
# Epoch 49/50
# 15/15 - 17s - loss: 1.3071 - accuracy: 0.9985 - val_loss_val: 2.2426 - val_val_accuracy: 0.9977
# Epoch 50/50
# 15/15 - 17s - loss: 1.3878 - accuracy: 0.9986 - val_loss_val: 2.2374 - val_val_accuracy: 0.9978
# 85/85 [==============================] - 15s 182ms/step - loss_val: 1.7873 - val_accuracy: 0.9983
# accuracy: 99.82752203941345
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 94.5%
#    recall: 94.4%
#  accuracy: 99.9%
#  F1-score: 94.5%
#             Class Name precision recall f1-score support  model
# 0                -fol3      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  785685  -fol3
# 2     B-CANCER_CONCEPT      0.96   0.96     0.96     627  -fol3
# 3       B-CHEMOTHERAPY      0.98   0.99     0.99     181  -fol3
# 4   B-CLINICAL_SERVICE      0.92   0.96     0.94     126  -fol3
# 5        B-COMORBIDITY      0.94   0.92     0.93     486  -fol3
# 6               B-DATE      0.96   0.96     0.96     854  -fol3
# 7               B-DRUG      0.97   0.97     0.97     926  -fol3
# 8             B-FAMILY      0.93   0.96     0.94      95  -fol3
# 9               B-FREQ      0.96   0.96     0.96     320  -fol3
# 10     B-IMPLICIT_DATE      0.80   0.84     0.82     108  -fol3
# 11            B-METRIC      0.97   0.97     0.97    1494  -fol3
# 12          B-MUTATION      0.99   0.99     0.99     172  -fol3
# 13   B-MUTATION_STATUS      0.95   0.97     0.96     144  -fol3
# 14   B-OCURRENCE_EVENT      0.93   0.94     0.94     456  -fol3
# 15          B-QUANTITY      0.98   0.96     0.97    1798  -fol3
# 16      B-RADIOTHERAPY      0.98   0.88     0.93     111  -fol3
# 17     B-SMOKER_STATUS      0.95   0.93     0.94     131  -fol3
# 18             B-STAGE      0.98   0.98     0.98     157  -fol3
# 19           B-SURGERY      0.91   0.84     0.87     133  -fol3
# 20               B-TNM      0.92   0.95     0.93     201  -fol3
# 21    I-CANCER_CONCEPT      0.96   0.96     0.96    1239  -fol3
# 22  I-CLINICAL_SERVICE      0.85   0.97     0.91      60  -fol3
# 23       I-COMORBIDITY      0.76   0.85     0.80     122  -fol3
# 24              I-DATE      0.98   0.99     0.99     594  -fol3
# 25              I-DRUG      0.99   0.92     0.95      79  -fol3
# 26            I-FAMILY      0.91   0.91     0.91      32  -fol3
# 27              I-FREQ      0.99   0.95     0.97     209  -fol3
# 28     I-IMPLICIT_DATE      0.86   0.94     0.89     221  -fol3
# 29            I-METRIC      0.95   0.98     0.96     285  -fol3
# 30          I-MUTATION      1.00   1.00     1.00      19  -fol3
# 31   I-MUTATION_STATUS      0.97   0.95     0.96     117  -fol3
# 32   I-OCURRENCE_EVENT      0.89   0.85     0.87     206  -fol3
# 33          I-QUANTITY      0.70   0.92     0.80      83  -fol3
# 34     I-SMOKER_STATUS      0.95   0.98     0.96      41  -fol3
# 35             I-STAGE      0.97   0.99     0.98     152  -fol3
# 36           I-SURGERY      0.88   0.85     0.86     164  -fol3
# 37               I-TNM      0.95   0.96     0.96     147  -fol3
# 38                   O      0.99   0.99     0.99   28225  -fol3
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# 15/15 - 27s - loss: 253.1571 - accuracy: 0.7782 - val_loss_val: 26.2428 - val_val_accuracy: 0.9846
# Epoch 2/50
# 15/15 - 17s - loss: 21.7785 - accuracy: 0.9848 - val_loss_val: 20.0337 - val_val_accuracy: 0.9846
# Epoch 3/50
# 15/15 - 17s - loss: 19.0931 - accuracy: 0.9841 - val_loss_val: 20.1854 - val_val_accuracy: 0.9849
# Epoch 4/50
# 15/15 - 17s - loss: 16.0831 - accuracy: 0.9869 - val_loss_val: 15.3408 - val_val_accuracy: 0.9880
# Epoch 5/50
# 15/15 - 17s - loss: 12.9628 - accuracy: 0.9893 - val_loss_val: 13.1290 - val_val_accuracy: 0.9894
# Epoch 6/50
# 15/15 - 17s - loss: 10.9624 - accuracy: 0.9906 - val_loss_val: 11.2358 - val_val_accuracy: 0.9904
# Epoch 7/50
# 15/15 - 17s - loss: 9.3856 - accuracy: 0.9918 - val_loss_val: 9.6850 - val_val_accuracy: 0.9915
# Epoch 8/50
# 15/15 - 17s - loss: 8.1339 - accuracy: 0.9927 - val_loss_val: 8.5310 - val_val_accuracy: 0.9925
# Epoch 9/50
# 15/15 - 17s - loss: 7.0967 - accuracy: 0.9936 - val_loss_val: 7.5310 - val_val_accuracy: 0.9933
# Epoch 10/50
# 15/15 - 17s - loss: 6.3229 - accuracy: 0.9943 - val_loss_val: 6.8382 - val_val_accuracy: 0.9939
# Epoch 11/50
# 15/15 - 17s - loss: 5.7475 - accuracy: 0.9948 - val_loss_val: 6.1894 - val_val_accuracy: 0.9943
# Epoch 12/50
# 15/15 - 17s - loss: 5.2243 - accuracy: 0.9952 - val_loss_val: 5.7120 - val_val_accuracy: 0.9946
# Epoch 13/50
# 15/15 - 17s - loss: 4.7670 - accuracy: 0.9956 - val_loss_val: 5.3194 - val_val_accuracy: 0.9951
# Epoch 14/50
# 15/15 - 17s - loss: 4.3748 - accuracy: 0.9959 - val_loss_val: 4.9992 - val_val_accuracy: 0.9953
# Epoch 15/50
# 15/15 - 17s - loss: 4.1756 - accuracy: 0.9961 - val_loss_val: 4.7873 - val_val_accuracy: 0.9955
# Epoch 16/50
# 15/15 - 17s - loss: 3.8937 - accuracy: 0.9964 - val_loss_val: 4.4480 - val_val_accuracy: 0.9958
# Epoch 17/50
# 15/15 - 17s - loss: 3.6624 - accuracy: 0.9966 - val_loss_val: 4.2732 - val_val_accuracy: 0.9958
# Epoch 18/50
# 15/15 - 17s - loss: 3.4226 - accuracy: 0.9967 - val_loss_val: 4.0807 - val_val_accuracy: 0.9959
# Epoch 19/50
# 15/15 - 17s - loss: 3.3594 - accuracy: 0.9969 - val_loss_val: 3.9571 - val_val_accuracy: 0.9961
# Epoch 20/50
# 15/15 - 17s - loss: 3.1868 - accuracy: 0.9969 - val_loss_val: 3.7086 - val_val_accuracy: 0.9963
# Epoch 21/50
# 15/15 - 17s - loss: 3.0078 - accuracy: 0.9971 - val_loss_val: 3.6377 - val_val_accuracy: 0.9963
# Epoch 22/50
# 15/15 - 17s - loss: 2.9355 - accuracy: 0.9972 - val_loss_val: 3.5829 - val_val_accuracy: 0.9965
# Epoch 23/50
# 15/15 - 17s - loss: 2.8715 - accuracy: 0.9972 - val_loss_val: 3.4878 - val_val_accuracy: 0.9966
# Epoch 24/50
# 15/15 - 17s - loss: 2.7299 - accuracy: 0.9973 - val_loss_val: 3.2760 - val_val_accuracy: 0.9966
# Epoch 25/50
# 15/15 - 17s - loss: 2.6161 - accuracy: 0.9974 - val_loss_val: 3.3294 - val_val_accuracy: 0.9966
# Epoch 26/50
# 15/15 - 17s - loss: 2.5846 - accuracy: 0.9975 - val_loss_val: 3.2239 - val_val_accuracy: 0.9967
# Epoch 27/50
# 15/15 - 17s - loss: 2.4792 - accuracy: 0.9975 - val_loss_val: 3.0731 - val_val_accuracy: 0.9968
# Epoch 28/50
# 15/15 - 17s - loss: 2.3739 - accuracy: 0.9976 - val_loss_val: 3.0779 - val_val_accuracy: 0.9969
# Epoch 29/50
# 15/15 - 17s - loss: 2.3822 - accuracy: 0.9976 - val_loss_val: 3.0123 - val_val_accuracy: 0.9969
# Epoch 30/50
# 15/15 - 17s - loss: 2.2866 - accuracy: 0.9977 - val_loss_val: 2.8514 - val_val_accuracy: 0.9970
# Epoch 31/50
# 15/15 - 17s - loss: 2.2469 - accuracy: 0.9977 - val_loss_val: 2.9286 - val_val_accuracy: 0.9971
# Epoch 32/50
# 15/15 - 17s - loss: 2.2025 - accuracy: 0.9978 - val_loss_val: 2.8736 - val_val_accuracy: 0.9971
# Epoch 33/50
# 15/15 - 17s - loss: 2.1785 - accuracy: 0.9978 - val_loss_val: 2.7850 - val_val_accuracy: 0.9972
# Epoch 34/50
# 15/15 - 17s - loss: 2.1524 - accuracy: 0.9979 - val_loss_val: 2.8579 - val_val_accuracy: 0.9971
# Epoch 35/50
# 15/15 - 17s - loss: 2.1078 - accuracy: 0.9979 - val_loss_val: 2.5898 - val_val_accuracy: 0.9972
# Epoch 36/50
# 15/15 - 17s - loss: 2.0133 - accuracy: 0.9979 - val_loss_val: 2.7419 - val_val_accuracy: 0.9971
# Epoch 37/50
# 15/15 - 17s - loss: 2.0060 - accuracy: 0.9980 - val_loss_val: 2.6687 - val_val_accuracy: 0.9971
# Epoch 38/50
# 15/15 - 17s - loss: 1.9135 - accuracy: 0.9980 - val_loss_val: 2.5558 - val_val_accuracy: 0.9973
# Epoch 39/50
# 15/15 - 17s - loss: 1.9234 - accuracy: 0.9980 - val_loss_val: 2.5290 - val_val_accuracy: 0.9974
# Epoch 40/50
# 15/15 - 17s - loss: 1.8681 - accuracy: 0.9981 - val_loss_val: 2.5004 - val_val_accuracy: 0.9973
# Epoch 41/50
# 15/15 - 17s - loss: 1.8512 - accuracy: 0.9981 - val_loss_val: 2.4875 - val_val_accuracy: 0.9974
# Epoch 42/50
# 15/15 - 17s - loss: 1.8058 - accuracy: 0.9981 - val_loss_val: 2.3474 - val_val_accuracy: 0.9974
# Epoch 43/50
# 15/15 - 17s - loss: 1.7525 - accuracy: 0.9982 - val_loss_val: 2.5398 - val_val_accuracy: 0.9974
# Epoch 44/50
# 15/15 - 17s - loss: 1.7423 - accuracy: 0.9982 - val_loss_val: 2.4528 - val_val_accuracy: 0.9974
# Epoch 45/50
# 15/15 - 17s - loss: 1.7001 - accuracy: 0.9982 - val_loss_val: 2.4922 - val_val_accuracy: 0.9974
# Epoch 46/50
# 15/15 - 17s - loss: 1.7263 - accuracy: 0.9982 - val_loss_val: 2.3307 - val_val_accuracy: 0.9975
# Epoch 47/50
# 15/15 - 17s - loss: 1.6539 - accuracy: 0.9982 - val_loss_val: 2.3915 - val_val_accuracy: 0.9975
# Epoch 48/50
# 15/15 - 17s - loss: 1.6491 - accuracy: 0.9982 - val_loss_val: 2.3079 - val_val_accuracy: 0.9975
# Epoch 49/50
# 15/15 - 17s - loss: 1.5714 - accuracy: 0.9983 - val_loss_val: 2.3822 - val_val_accuracy: 0.9975
# Epoch 50/50
# 15/15 - 17s - loss: 1.5977 - accuracy: 0.9983 - val_loss_val: 2.2958 - val_val_accuracy: 0.9975
# 85/85 [==============================] - 14s 161ms/step - loss_val: 2.0806 - val_accuracy: 0.9979
# accuracy: 99.79097247123718
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 93.0%
#    recall: 93.3%
#  accuracy: 99.9%
#  F1-score: 93.1%
#             Class Name precision recall f1-score support  model
# 0                -fol4      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  784870  -fol4
# 2     B-CANCER_CONCEPT      0.95   0.95     0.95     744  -fol4
# 3       B-CHEMOTHERAPY      0.98   0.98     0.98     179  -fol4
# 4   B-CLINICAL_SERVICE      0.89   0.95     0.92     131  -fol4
# 5        B-COMORBIDITY      0.91   0.91     0.91     468  -fol4
# 6               B-DATE      0.95   0.95     0.95     761  -fol4
# 7               B-DRUG      0.95   0.96     0.95     928  -fol4
# 8             B-FAMILY      0.93   0.99     0.96     136  -fol4
# 9               B-FREQ      0.94   0.95     0.94     328  -fol4
# 10     B-IMPLICIT_DATE      0.75   0.81     0.78     113  -fol4
# 11            B-METRIC      0.97   0.96     0.96    1571  -fol4
# 12          B-MUTATION      1.00   0.99     0.99     194  -fol4
# 13   B-MUTATION_STATUS      0.96   0.97     0.96     151  -fol4
# 14   B-OCURRENCE_EVENT      0.94   0.97     0.96     515  -fol4
# 15          B-QUANTITY      0.97   0.96     0.96    1853  -fol4
# 16      B-RADIOTHERAPY      0.96   0.92     0.94     109  -fol4
# 17     B-SMOKER_STATUS      0.96   0.90     0.93     115  -fol4
# 18             B-STAGE      0.96   0.99     0.97     154  -fol4
# 19           B-SURGERY      0.98   0.81     0.89     156  -fol4
# 20               B-TNM      0.89   0.92     0.91     216  -fol4
# 21    I-CANCER_CONCEPT      0.93   0.96     0.95    1506  -fol4
# 22  I-CLINICAL_SERVICE      0.93   0.96     0.95      81  -fol4
# 23       I-COMORBIDITY      0.72   0.89     0.79     122  -fol4
# 24              I-DATE      0.99   0.99     0.99     472  -fol4
# 25              I-DRUG      0.95   0.86     0.90      86  -fol4
# 26            I-FAMILY      0.94   0.96     0.95      53  -fol4
# 27              I-FREQ      0.99   0.96     0.97     232  -fol4
# 28     I-IMPLICIT_DATE      0.84   0.94     0.89     231  -fol4
# 29            I-METRIC      0.98   0.96     0.97     338  -fol4
# 30          I-MUTATION      1.00   0.92     0.96      24  -fol4
# 31   I-MUTATION_STATUS      0.92   0.99     0.95     124  -fol4
# 32   I-OCURRENCE_EVENT      0.93   0.87     0.90     230  -fol4
# 33          I-QUANTITY      0.72   0.83     0.77      87  -fol4
# 34     I-SMOKER_STATUS      0.93   1.00     0.96      39  -fol4
# 35             I-STAGE      0.96   0.99     0.97     151  -fol4
# 36           I-SURGERY      0.91   0.87     0.89     179  -fol4
# 37               I-TNM      0.95   0.93     0.94     169  -fol4
# 38                   O      0.98   0.98     0.98   28384  -fol4
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = nccl, num_packs = 1
# 15/15 - 27s - loss: 333.1058 - accuracy: 0.7320 - val_loss_val: 28.6580 - val_val_accuracy: 0.9843
# Epoch 2/50
# 15/15 - 17s - loss: 25.4319 - accuracy: 0.9848 - val_loss_val: 23.8588 - val_val_accuracy: 0.9845
# Epoch 3/50
# 15/15 - 17s - loss: 21.2157 - accuracy: 0.9848 - val_loss_val: 21.0357 - val_val_accuracy: 0.9846
# Epoch 4/50
# 15/15 - 17s - loss: 18.6680 - accuracy: 0.9852 - val_loss_val: 18.8767 - val_val_accuracy: 0.9853
# Epoch 5/50
# 15/15 - 17s - loss: 16.6359 - accuracy: 0.9866 - val_loss_val: 17.0171 - val_val_accuracy: 0.9872
# Epoch 6/50
# 15/15 - 17s - loss: 14.8517 - accuracy: 0.9884 - val_loss_val: 15.3428 - val_val_accuracy: 0.9883
# Epoch 7/50
# 15/15 - 17s - loss: 13.1626 - accuracy: 0.9896 - val_loss_val: 13.6411 - val_val_accuracy: 0.9893
# Epoch 8/50
# 15/15 - 17s - loss: 11.6659 - accuracy: 0.9906 - val_loss_val: 12.2643 - val_val_accuracy: 0.9902
# Epoch 9/50
# 15/15 - 17s - loss: 10.4896 - accuracy: 0.9915 - val_loss_val: 11.0481 - val_val_accuracy: 0.9910
# Epoch 10/50
# 15/15 - 17s - loss: 9.3648 - accuracy: 0.9922 - val_loss_val: 9.9554 - val_val_accuracy: 0.9916
# Epoch 11/50
# 15/15 - 17s - loss: 8.4170 - accuracy: 0.9928 - val_loss_val: 8.8248 - val_val_accuracy: 0.9923
# Epoch 12/50
# 15/15 - 17s - loss: 7.5049 - accuracy: 0.9934 - val_loss_val: 8.1166 - val_val_accuracy: 0.9929
# Epoch 13/50
# 15/15 - 17s - loss: 6.8222 - accuracy: 0.9940 - val_loss_val: 7.5482 - val_val_accuracy: 0.9932
# Epoch 14/50
# 15/15 - 17s - loss: 6.2353 - accuracy: 0.9944 - val_loss_val: 6.8793 - val_val_accuracy: 0.9937
# Epoch 15/50
# 15/15 - 17s - loss: 5.7326 - accuracy: 0.9949 - val_loss_val: 6.3830 - val_val_accuracy: 0.9943
# Epoch 16/50
# 15/15 - 17s - loss: 5.2158 - accuracy: 0.9953 - val_loss_val: 5.7839 - val_val_accuracy: 0.9947
# Epoch 17/50
# 15/15 - 17s - loss: 4.8130 - accuracy: 0.9956 - val_loss_val: 5.4292 - val_val_accuracy: 0.9950
# Epoch 18/50
# 15/15 - 17s - loss: 4.5419 - accuracy: 0.9959 - val_loss_val: 5.2212 - val_val_accuracy: 0.9953
# Epoch 19/50
# 15/15 - 17s - loss: 4.3438 - accuracy: 0.9961 - val_loss_val: 5.0396 - val_val_accuracy: 0.9954
# Epoch 20/50
# 15/15 - 17s - loss: 4.0153 - accuracy: 0.9964 - val_loss_val: 4.6060 - val_val_accuracy: 0.9956
# Epoch 21/50
# 15/15 - 17s - loss: 3.8272 - accuracy: 0.9965 - val_loss_val: 4.5341 - val_val_accuracy: 0.9958
# Epoch 22/50
# 15/15 - 17s - loss: 3.6947 - accuracy: 0.9966 - val_loss_val: 4.2876 - val_val_accuracy: 0.9960
# Epoch 23/50
# 15/15 - 17s - loss: 3.5218 - accuracy: 0.9968 - val_loss_val: 3.9695 - val_val_accuracy: 0.9961
# Epoch 24/50
# 15/15 - 17s - loss: 3.2803 - accuracy: 0.9969 - val_loss_val: 3.9559 - val_val_accuracy: 0.9962
# Epoch 25/50
# 15/15 - 17s - loss: 3.2549 - accuracy: 0.9969 - val_loss_val: 3.9492 - val_val_accuracy: 0.9963
# Epoch 26/50
# 15/15 - 17s - loss: 3.2320 - accuracy: 0.9970 - val_loss_val: 3.8856 - val_val_accuracy: 0.9964
# Epoch 27/50
# 15/15 - 17s - loss: 3.0127 - accuracy: 0.9971 - val_loss_val: 3.6109 - val_val_accuracy: 0.9963
# Epoch 28/50
# 15/15 - 17s - loss: 2.9307 - accuracy: 0.9972 - val_loss_val: 3.6315 - val_val_accuracy: 0.9965
# Epoch 29/50
# 15/15 - 17s - loss: 2.9546 - accuracy: 0.9972 - val_loss_val: 3.6423 - val_val_accuracy: 0.9965
# Epoch 30/50
# 15/15 - 17s - loss: 2.7389 - accuracy: 0.9973 - val_loss_val: 3.3592 - val_val_accuracy: 0.9965
# Epoch 31/50
# 15/15 - 17s - loss: 2.7150 - accuracy: 0.9974 - val_loss_val: 3.4152 - val_val_accuracy: 0.9967
# Epoch 32/50
# 15/15 - 17s - loss: 2.7331 - accuracy: 0.9974 - val_loss_val: 3.1591 - val_val_accuracy: 0.9968
# Epoch 33/50
# 15/15 - 17s - loss: 2.5014 - accuracy: 0.9975 - val_loss_val: 3.2120 - val_val_accuracy: 0.9968
# Epoch 34/50
# 15/15 - 17s - loss: 2.5402 - accuracy: 0.9975 - val_loss_val: 3.2300 - val_val_accuracy: 0.9968
# Epoch 35/50
# 15/15 - 17s - loss: 2.5021 - accuracy: 0.9976 - val_loss_val: 3.1100 - val_val_accuracy: 0.9968
# Epoch 36/50
# 15/15 - 17s - loss: 2.3922 - accuracy: 0.9976 - val_loss_val: 3.1832 - val_val_accuracy: 0.9968
# Epoch 37/50
# 15/15 - 17s - loss: 2.4381 - accuracy: 0.9976 - val_loss_val: 3.1328 - val_val_accuracy: 0.9970
# Epoch 38/50
# 15/15 - 17s - loss: 2.2961 - accuracy: 0.9977 - val_loss_val: 2.9508 - val_val_accuracy: 0.9970
# Epoch 39/50
# 15/15 - 17s - loss: 2.2965 - accuracy: 0.9977 - val_loss_val: 2.9744 - val_val_accuracy: 0.9970
# Epoch 40/50
# 15/15 - 17s - loss: 2.2581 - accuracy: 0.9977 - val_loss_val: 2.8161 - val_val_accuracy: 0.9970
# Epoch 41/50
# 15/15 - 17s - loss: 2.1379 - accuracy: 0.9978 - val_loss_val: 2.9148 - val_val_accuracy: 0.9971
# Epoch 42/50
# 15/15 - 17s - loss: 2.2238 - accuracy: 0.9978 - val_loss_val: 2.7025 - val_val_accuracy: 0.9971
# Epoch 43/50
# 15/15 - 17s - loss: 2.0872 - accuracy: 0.9978 - val_loss_val: 2.7488 - val_val_accuracy: 0.9972
# Epoch 44/50
# 15/15 - 17s - loss: 2.1267 - accuracy: 0.9979 - val_loss_val: 2.9248 - val_val_accuracy: 0.9971
# Epoch 45/50
# 15/15 - 17s - loss: 1.9790 - accuracy: 0.9979 - val_loss_val: 2.6400 - val_val_accuracy: 0.9973
# Epoch 46/50
# 15/15 - 17s - loss: 2.0445 - accuracy: 0.9979 - val_loss_val: 2.7735 - val_val_accuracy: 0.9973
# Epoch 47/50
# 15/15 - 17s - loss: 1.9708 - accuracy: 0.9980 - val_loss_val: 2.5788 - val_val_accuracy: 0.9973
# Epoch 48/50
# 15/15 - 17s - loss: 1.9560 - accuracy: 0.9980 - val_loss_val: 2.6948 - val_val_accuracy: 0.9972
# Epoch 49/50
# 15/15 - 17s - loss: 1.9206 - accuracy: 0.9980 - val_loss_val: 2.6781 - val_val_accuracy: 0.9971
# Epoch 50/50
# 15/15 - 17s - loss: 1.8742 - accuracy: 0.9981 - val_loss_val: 2.6803 - val_val_accuracy: 0.9973
# 85/85 [==============================] - 13s 151ms/step - loss_val: 2.3252 - val_accuracy: 0.9977
# accuracy: 99.7551441192627
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 93.6%
#    recall: 92.0%
#  accuracy: 99.9%
#  F1-score: 92.8%
#             Class Name precision recall f1-score support  model
# 0                -fol5      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  785513  -fol5
# 2     B-CANCER_CONCEPT      0.96   0.93     0.95     705  -fol5
# 3       B-CHEMOTHERAPY      0.99   1.00     0.99     176  -fol5
# 4   B-CLINICAL_SERVICE      0.93   0.94     0.94     125  -fol5
# 5        B-COMORBIDITY      0.91   0.87     0.89     503  -fol5
# 6               B-DATE      0.97   0.92     0.94     779  -fol5
# 7               B-DRUG      0.96   0.95     0.96     872  -fol5
# 8             B-FAMILY      0.98   0.97     0.97     128  -fol5
# 9               B-FREQ      0.96   0.95     0.95     319  -fol5
# 10     B-IMPLICIT_DATE      0.86   0.82     0.84     120  -fol5
# 11            B-METRIC      0.97   0.94     0.96    1546  -fol5
# 12          B-MUTATION      0.99   0.99     0.99     168  -fol5
# 13   B-MUTATION_STATUS      0.97   0.96     0.97     131  -fol5
# 14   B-OCURRENCE_EVENT      0.92   0.96     0.94     510  -fol5
# 15          B-QUANTITY      0.97   0.95     0.96    1819  -fol5
# 16      B-RADIOTHERAPY      0.96   0.93     0.95     105  -fol5
# 17     B-SMOKER_STATUS      1.00   0.95     0.97      97  -fol5
# 18             B-STAGE      0.98   0.96     0.97     165  -fol5
# 19           B-SURGERY      0.93   0.84     0.88     136  -fol5
# 20               B-TNM      0.89   0.91     0.90     211  -fol5
# 21    I-CANCER_CONCEPT      0.95   0.96     0.95    1385  -fol5
# 22  I-CLINICAL_SERVICE      0.98   0.87     0.93      71  -fol5
# 23       I-COMORBIDITY      0.85   0.55     0.66     143  -fol5
# 24              I-DATE      0.98   0.99     0.98     534  -fol5
# 25              I-DRUG      0.97   0.72     0.83      54  -fol5
# 26            I-FAMILY      0.97   0.97     0.97      35  -fol5
# 27              I-FREQ      0.95   0.91     0.93     203  -fol5
# 28     I-IMPLICIT_DATE      0.96   0.91     0.94     242  -fol5
# 29            I-METRIC      0.96   0.96     0.96     260  -fol5
# 30          I-MUTATION      1.00   1.00     1.00      17  -fol5
# 31   I-MUTATION_STATUS      0.96   0.96     0.96     113  -fol5
# 32   I-OCURRENCE_EVENT      0.89   0.88     0.89     242  -fol5
# 33          I-QUANTITY      0.62   0.66     0.64      59  -fol5
# 34     I-SMOKER_STATUS      1.00   1.00     1.00      39  -fol5
# 35             I-STAGE      0.99   0.99     0.99     155  -fol5
# 36           I-SURGERY      0.84   0.82     0.83     168  -fol5
# 37               I-TNM      0.97   0.93     0.95     161  -fol5
# 38                   O      0.98   0.99     0.98   28191  -fol5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# ...
# Epoch 12/50
# 15/15 - 17s - loss: 8.1313 - accuracy: 0.9928 - val_loss_val: 8.7208 - val_val_accuracy: 0.9921
# Epoch 13/50
# 15/15 - 17s - loss: 7.2190 - accuracy: 0.9934 - val_loss_val: 7.9175 - val_val_accuracy: 0.9927
# Epoch 14/50
# 15/15 - 17s - loss: 6.4565 - accuracy: 0.9941 - val_loss_val: 7.1137 - val_val_accuracy: 0.9934
# Epoch 15/50
# 15/15 - 17s - loss: 5.8430 - accuracy: 0.9946 - val_loss_val: 6.4792 - val_val_accuracy: 0.9940
# Epoch 16/50
# 15/15 - 17s - loss: 5.3625 - accuracy: 0.9950 - val_loss_val: 5.9218 - val_val_accuracy: 0.9943
# Epoch 17/50
# 15/15 - 17s - loss: 4.8895 - accuracy: 0.9954 - val_loss_val: 5.4413 - val_val_accuracy: 0.9948
# Epoch 18/50
# 15/15 - 17s - loss: 4.5306 - accuracy: 0.9957 - val_loss_val: 5.0678 - val_val_accuracy: 0.9951
# Epoch 19/50
# 15/15 - 17s - loss: 4.2196 - accuracy: 0.9960 - val_loss_val: 4.7956 - val_val_accuracy: 0.9954
# Epoch 20/50
# 15/15 - 17s - loss: 3.9460 - accuracy: 0.9963 - val_loss_val: 4.5254 - val_val_accuracy: 0.9955
# Epoch 21/50
# 15/15 - 17s - loss: 3.7663 - accuracy: 0.9964 - val_loss_val: 4.4195 - val_val_accuracy: 0.9957
# Epoch 22/50
# 15/15 - 17s - loss: 3.5366 - accuracy: 0.9966 - val_loss_val: 4.2522 - val_val_accuracy: 0.9958
# Epoch 23/50
# 15/15 - 17s - loss: 3.4519 - accuracy: 0.9966 - val_loss_val: 3.9692 - val_val_accuracy: 0.9960
# Epoch 24/50
# 15/15 - 17s - loss: 3.2702 - accuracy: 0.9968 - val_loss_val: 3.9324 - val_val_accuracy: 0.9961
# Epoch 25/50
# 15/15 - 17s - loss: 3.1740 - accuracy: 0.9969 - val_loss_val: 3.8510 - val_val_accuracy: 0.9962
# Epoch 26/50
# 15/15 - 17s - loss: 3.0635 - accuracy: 0.9970 - val_loss_val: 3.6140 - val_val_accuracy: 0.9963
# Epoch 27/50
# 15/15 - 17s - loss: 2.9595 - accuracy: 0.9971 - val_loss_val: 3.5525 - val_val_accuracy: 0.9965
# Epoch 28/50
# 15/15 - 17s - loss: 2.8430 - accuracy: 0.9971 - val_loss_val: 3.5013 - val_val_accuracy: 0.9963
# Epoch 29/50
# 15/15 - 17s - loss: 2.7921 - accuracy: 0.9972 - val_loss_val: 3.4097 - val_val_accuracy: 0.9965
# Epoch 30/50
# 15/15 - 17s - loss: 2.7422 - accuracy: 0.9972 - val_loss_val: 3.2984 - val_val_accuracy: 0.9965
# Epoch 31/50
# 15/15 - 17s - loss: 2.6394 - accuracy: 0.9973 - val_loss_val: 3.3472 - val_val_accuracy: 0.9966
# Epoch 32/50
# 15/15 - 17s - loss: 2.5836 - accuracy: 0.9974 - val_loss_val: 3.2693 - val_val_accuracy: 0.9965
# Epoch 33/50
# 15/15 - 17s - loss: 2.5204 - accuracy: 0.9974 - val_loss_val: 3.1624 - val_val_accuracy: 0.9967
# Epoch 34/50
# 15/15 - 17s - loss: 2.5200 - accuracy: 0.9974 - val_loss_val: 3.0794 - val_val_accuracy: 0.9967
# Epoch 35/50
# 15/15 - 17s - loss: 2.4383 - accuracy: 0.9975 - val_loss_val: 3.0306 - val_val_accuracy: 0.9967
# Epoch 36/50
# 15/15 - 17s - loss: 2.3795 - accuracy: 0.9975 - val_loss_val: 2.9470 - val_val_accuracy: 0.9969
# Epoch 37/50
# 15/15 - 17s - loss: 2.3104 - accuracy: 0.9976 - val_loss_val: 2.9836 - val_val_accuracy: 0.9969
# Epoch 38/50
# 15/15 - 17s - loss: 2.3103 - accuracy: 0.9976 - val_loss_val: 2.9685 - val_val_accuracy: 0.9968
# Epoch 39/50
# 15/15 - 17s - loss: 2.2798 - accuracy: 0.9976 - val_loss_val: 2.9158 - val_val_accuracy: 0.9969
# Epoch 40/50
# 15/15 - 17s - loss: 2.2025 - accuracy: 0.9977 - val_loss_val: 2.8236 - val_val_accuracy: 0.9970
# Epoch 41/50
# 15/15 - 17s - loss: 2.1886 - accuracy: 0.9977 - val_loss_val: 2.8024 - val_val_accuracy: 0.9970
# Epoch 42/50
# 15/15 - 17s - loss: 2.1358 - accuracy: 0.9978 - val_loss_val: 2.6991 - val_val_accuracy: 0.9970
# Epoch 43/50
# 15/15 - 17s - loss: 2.1011 - accuracy: 0.9978 - val_loss_val: 2.6628 - val_val_accuracy: 0.9971
# Epoch 44/50
# 15/15 - 17s - loss: 2.0370 - accuracy: 0.9979 - val_loss_val: 2.6800 - val_val_accuracy: 0.9971
# Epoch 45/50
# 15/15 - 17s - loss: 2.0277 - accuracy: 0.9978 - val_loss_val: 2.6067 - val_val_accuracy: 0.9971
# Epoch 46/50
# 15/15 - 17s - loss: 2.0199 - accuracy: 0.9978 - val_loss_val: 2.5900 - val_val_accuracy: 0.9971
# Epoch 47/50
# 15/15 - 17s - loss: 1.9514 - accuracy: 0.9979 - val_loss_val: 2.6092 - val_val_accuracy: 0.9971
# Epoch 48/50
# 15/15 - 17s - loss: 1.9479 - accuracy: 0.9980 - val_loss_val: 2.6002 - val_val_accuracy: 0.9971
# Epoch 49/50
# 15/15 - 17s - loss: 1.9058 - accuracy: 0.9980 - val_loss_val: 2.5545 - val_val_accuracy: 0.9971
# Epoch 50/50
# 15/15 - 17s - loss: 1.8557 - accuracy: 0.9980 - val_loss_val: 2.4873 - val_val_accuracy: 0.9973
# 85/85 [==============================] - 14s 162ms/step - loss_val: 1.9912 - val_accuracy: 0.9979
# accuracy: 99.77439045906067
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 93.3%
#    recall: 92.8%
#  accuracy: 99.9%
#  F1-score: 93.1%
#             Class Name precision recall f1-score support  model
# 0                -fol6      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  786357  -fol6
# 2     B-CANCER_CONCEPT      0.95   0.95     0.95     649  -fol6
# 3       B-CHEMOTHERAPY      0.97   0.99     0.98     183  -fol6
# 4   B-CLINICAL_SERVICE      0.91   0.95     0.93     114  -fol6
# 5        B-COMORBIDITY      0.93   0.88     0.90     494  -fol6
# 6               B-DATE      0.93   0.93     0.93     863  -fol6
# 7               B-DRUG      0.96   0.96     0.96     936  -fol6
# 8             B-FAMILY      0.99   0.92     0.96      92  -fol6
# 9               B-FREQ      0.91   0.96     0.93     300  -fol6
# 10     B-IMPLICIT_DATE      0.79   0.81     0.79     118  -fol6
# 11            B-METRIC      0.97   0.97     0.97    1478  -fol6
# 12          B-MUTATION      0.99   0.97     0.98     237  -fol6
# 13   B-MUTATION_STATUS      0.94   0.96     0.95     175  -fol6
# 14   B-OCURRENCE_EVENT      0.94   0.94     0.94     508  -fol6
# 15          B-QUANTITY      0.97   0.94     0.96    1807  -fol6
# 16      B-RADIOTHERAPY      0.98   0.94     0.96      99  -fol6
# 17     B-SMOKER_STATUS      0.94   0.90     0.92     113  -fol6
# 18             B-STAGE      0.93   0.95     0.94     157  -fol6
# 19           B-SURGERY      0.97   0.88     0.92     112  -fol6
# 20               B-TNM      0.88   0.91     0.90     195  -fol6
# 21    I-CANCER_CONCEPT      0.92   0.97     0.94    1248  -fol6
# 22  I-CLINICAL_SERVICE      0.95   0.97     0.96      63  -fol6
# 23       I-COMORBIDITY      0.84   0.77     0.80     133  -fol6
# 24              I-DATE      0.99   0.98     0.99     593  -fol6
# 25              I-DRUG      0.95   0.93     0.94      90  -fol6
# 26            I-FAMILY      0.93   0.93     0.93      27  -fol6
# 27              I-FREQ      0.94   0.97     0.95     195  -fol6
# 28     I-IMPLICIT_DATE      0.88   0.93     0.91     242  -fol6
# 29            I-METRIC      0.96   0.95     0.95     275  -fol6
# 30          I-MUTATION      1.00   0.92     0.96      25  -fol6
# 31   I-MUTATION_STATUS      0.96   1.00     0.98     152  -fol6
# 32   I-OCURRENCE_EVENT      0.87   0.82     0.84     222  -fol6
# 33          I-QUANTITY      0.82   0.79     0.81      68  -fol6
# 34     I-SMOKER_STATUS      1.00   0.96     0.98      24  -fol6
# 35             I-STAGE      0.95   0.96     0.96     150  -fol6
# 36           I-SURGERY      0.92   0.90     0.91     119  -fol6
# 37               I-TNM      0.95   0.98     0.97     128  -fol6
# 38                   O      0.98   0.98     0.98   27459  -fol6
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# Epoch 1/50
# 15/15 - 27s - loss: 337.1378 - accuracy: 0.7016 - val_loss_val: 70.8494 - val_val_accuracy: 0.9505
# Epoch 2/50
# 15/15 - 17s - loss: 43.5867 - accuracy: 0.9529 - val_loss_val: 32.9917 - val_val_accuracy: 0.9794
# Epoch 3/50
# 15/15 - 17s - loss: 28.0359 - accuracy: 0.9840 - val_loss_val: 25.4456 - val_val_accuracy: 0.9843
# Epoch 4/50
# 15/15 - 17s - loss: 22.2834 - accuracy: 0.9846 - val_loss_val: 21.8372 - val_val_accuracy: 0.9844
# Epoch 5/50
# 15/15 - 17s - loss: 19.8344 - accuracy: 0.9848 - val_loss_val: 20.2237 - val_val_accuracy: 0.9850
# Epoch 6/50
# 15/15 - 17s - loss: 18.3094 - accuracy: 0.9858 - val_loss_val: 18.6313 - val_val_accuracy: 0.9860
# Epoch 7/50
# 15/15 - 17s - loss: 16.6739 - accuracy: 0.9865 - val_loss_val: 17.2901 - val_val_accuracy: 0.9866
# Epoch 8/50
# 15/15 - 17s - loss: 15.3019 - accuracy: 0.9871 - val_loss_val: 15.9160 - val_val_accuracy: 0.9870
# Epoch 9/50
# 15/15 - 17s - loss: 13.8687 - accuracy: 0.9880 - val_loss_val: 14.5232 - val_val_accuracy: 0.9880
# Epoch 10/50
# 15/15 - 17s - loss: 12.5047 - accuracy: 0.9894 - val_loss_val: 13.1316 - val_val_accuracy: 0.9893
# Epoch 11/50
# 15/15 - 17s - loss: 11.0511 - accuracy: 0.9907 - val_loss_val: 11.7622 - val_val_accuracy: 0.9901
# Epoch 12/50
# 15/15 - 17s - loss: 9.9344 - accuracy: 0.9913 - val_loss_val: 10.6002 - val_val_accuracy: 0.9908
# Epoch 13/50
# 15/15 - 17s - loss: 8.9956 - accuracy: 0.9919 - val_loss_val: 9.7898 - val_val_accuracy: 0.9914
# Epoch 14/50
# 15/15 - 17s - loss: 8.1215 - accuracy: 0.9927 - val_loss_val: 8.7591 - val_val_accuracy: 0.9922
# Epoch 15/50
# 15/15 - 17s - loss: 7.4467 - accuracy: 0.9933 - val_loss_val: 8.1606 - val_val_accuracy: 0.9928
# Epoch 16/50
# 15/15 - 17s - loss: 6.9012 - accuracy: 0.9938 - val_loss_val: 7.6798 - val_val_accuracy: 0.9932
# Epoch 17/50
# 15/15 - 17s - loss: 6.4851 - accuracy: 0.9942 - val_loss_val: 7.1830 - val_val_accuracy: 0.9936
# Epoch 18/50
# 15/15 - 17s - loss: 6.0720 - accuracy: 0.9946 - val_loss_val: 6.5208 - val_val_accuracy: 0.9939
# Epoch 19/50
# 15/15 - 17s - loss: 5.4708 - accuracy: 0.9950 - val_loss_val: 6.1958 - val_val_accuracy: 0.9942
# Epoch 20/50
# 15/15 - 17s - loss: 5.1317 - accuracy: 0.9952 - val_loss_val: 5.8599 - val_val_accuracy: 0.9946
# Epoch 21/50
# 15/15 - 17s - loss: 4.8734 - accuracy: 0.9956 - val_loss_val: 5.5698 - val_val_accuracy: 0.9948
# Epoch 22/50
# 15/15 - 17s - loss: 4.5624 - accuracy: 0.9958 - val_loss_val: 5.0766 - val_val_accuracy: 0.9951
# Epoch 23/50
# 15/15 - 17s - loss: 4.1616 - accuracy: 0.9961 - val_loss_val: 4.7988 - val_val_accuracy: 0.9953
# Epoch 24/50
# 15/15 - 17s - loss: 3.9803 - accuracy: 0.9963 - val_loss_val: 4.6867 - val_val_accuracy: 0.9955
# Epoch 25/50
# 15/15 - 17s - loss: 3.8757 - accuracy: 0.9964 - val_loss_val: 4.5386 - val_val_accuracy: 0.9957
# Epoch 26/50
# 15/15 - 17s - loss: 3.5973 - accuracy: 0.9966 - val_loss_val: 4.1998 - val_val_accuracy: 0.9959
# Epoch 27/50
# 15/15 - 17s - loss: 3.4539 - accuracy: 0.9967 - val_loss_val: 4.2051 - val_val_accuracy: 0.9959
# Epoch 28/50
# 15/15 - 17s - loss: 3.4363 - accuracy: 0.9968 - val_loss_val: 4.0596 - val_val_accuracy: 0.9961
# Epoch 29/50
# 15/15 - 17s - loss: 3.3037 - accuracy: 0.9968 - val_loss_val: 3.8616 - val_val_accuracy: 0.9961
# Epoch 30/50
# 15/15 - 17s - loss: 3.1002 - accuracy: 0.9969 - val_loss_val: 3.7573 - val_val_accuracy: 0.9962
# Epoch 31/50
# 15/15 - 17s - loss: 3.0890 - accuracy: 0.9970 - val_loss_val: 3.7961 - val_val_accuracy: 0.9963
# Epoch 32/50
# 15/15 - 17s - loss: 2.9874 - accuracy: 0.9970 - val_loss_val: 3.4728 - val_val_accuracy: 0.9964
# Epoch 33/50
# 15/15 - 17s - loss: 2.8177 - accuracy: 0.9971 - val_loss_val: 3.5551 - val_val_accuracy: 0.9965
# Epoch 34/50
# 15/15 - 17s - loss: 2.8803 - accuracy: 0.9972 - val_loss_val: 3.5312 - val_val_accuracy: 0.9965
# Epoch 35/50
# 15/15 - 17s - loss: 2.7473 - accuracy: 0.9972 - val_loss_val: 3.3487 - val_val_accuracy: 0.9966
# Epoch 36/50
# 15/15 - 17s - loss: 2.6583 - accuracy: 0.9973 - val_loss_val: 3.3940 - val_val_accuracy: 0.9966
# Epoch 37/50
# 15/15 - 17s - loss: 2.6848 - accuracy: 0.9974 - val_loss_val: 3.4178 - val_val_accuracy: 0.9965
# Epoch 38/50
# 15/15 - 17s - loss: 2.5114 - accuracy: 0.9974 - val_loss_val: 3.1665 - val_val_accuracy: 0.9966
# Epoch 39/50
# 15/15 - 17s - loss: 2.5490 - accuracy: 0.9974 - val_loss_val: 3.1082 - val_val_accuracy: 0.9968
# Epoch 40/50
# 15/15 - 17s - loss: 2.4677 - accuracy: 0.9975 - val_loss_val: 3.0461 - val_val_accuracy: 0.9967
# Epoch 41/50
# 15/15 - 17s - loss: 2.3774 - accuracy: 0.9976 - val_loss_val: 3.0675 - val_val_accuracy: 0.9969
# Epoch 42/50
# 15/15 - 17s - loss: 2.4620 - accuracy: 0.9975 - val_loss_val: 3.0687 - val_val_accuracy: 0.9969
# Epoch 43/50
# 15/15 - 17s - loss: 2.2676 - accuracy: 0.9976 - val_loss_val: 2.8604 - val_val_accuracy: 0.9970
# Epoch 44/50
# 15/15 - 17s - loss: 2.3226 - accuracy: 0.9976 - val_loss_val: 2.9367 - val_val_accuracy: 0.9970
# Epoch 45/50
# 15/15 - 17s - loss: 2.2431 - accuracy: 0.9977 - val_loss_val: 2.8365 - val_val_accuracy: 0.9970
# Epoch 46/50
# 15/15 - 17s - loss: 2.1814 - accuracy: 0.9977 - val_loss_val: 2.9097 - val_val_accuracy: 0.9970
# Epoch 47/50
# 15/15 - 17s - loss: 2.2126 - accuracy: 0.9977 - val_loss_val: 2.6947 - val_val_accuracy: 0.9971
# Epoch 48/50
# 15/15 - 17s - loss: 2.0891 - accuracy: 0.9978 - val_loss_val: 2.8255 - val_val_accuracy: 0.9971
# Epoch 49/50
# 15/15 - 17s - loss: 2.1655 - accuracy: 0.9978 - val_loss_val: 2.5787 - val_val_accuracy: 0.9971
# Epoch 50/50
# 15/15 - 17s - loss: 2.0143 - accuracy: 0.9978 - val_loss_val: 2.6796 - val_val_accuracy: 0.9972
# 85/85 [==============================] - 13s 157ms/step - loss_val: 2.3761 - val_accuracy: 0.9976
# accuracy: 99.75005984306335
# /home/ambientes/python3.8/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -PAD- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# precision: 92.8%
#    recall: 92.4%
#  accuracy: 99.8%
#  F1-score: 92.6%
#             Class Name precision recall f1-score support  model
# 0                -fol7      None   None     None    None   None
# 1                -PAD-      1.00   1.00     1.00  784897  -fol7
# 2     B-CANCER_CONCEPT      0.95   0.94     0.95     661  -fol7
# 3       B-CHEMOTHERAPY      0.98   0.98     0.98     189  -fol7
# 4   B-CLINICAL_SERVICE      0.94   0.93     0.93     153  -fol7
# 5        B-COMORBIDITY      0.89   0.88     0.88     484  -fol7
# 6               B-DATE      0.95   0.91     0.93     818  -fol7
# 7               B-DRUG      0.94   0.97     0.96     958  -fol7
# 8             B-FAMILY      0.97   0.99     0.98     117  -fol7
# 9               B-FREQ      0.92   0.94     0.93     351  -fol7
# 10     B-IMPLICIT_DATE      0.81   0.85     0.83     119  -fol7
# 11            B-METRIC      0.97   0.96     0.96    1572  -fol7
# 12          B-MUTATION      1.00   0.97     0.98     206  -fol7
# 13   B-MUTATION_STATUS      0.97   0.96     0.96     156  -fol7
# 14   B-OCURRENCE_EVENT      0.93   0.88     0.91     515  -fol7
# 15          B-QUANTITY      0.97   0.96     0.96    1868  -fol7
# 16      B-RADIOTHERAPY      0.93   0.93     0.93     114  -fol7
# 17     B-SMOKER_STATUS      0.97   0.90     0.93     124  -fol7
# 18             B-STAGE      0.95   0.97     0.96     159  -fol7
# 19           B-SURGERY      0.89   0.90     0.90     138  -fol7
# 20               B-TNM      0.86   0.89     0.88     229  -fol7
# 21    I-CANCER_CONCEPT      0.93   0.97     0.95    1279  -fol7
# 22  I-CLINICAL_SERVICE      0.95   0.84     0.89      83  -fol7
# 23       I-COMORBIDITY      0.72   0.67     0.70     137  -fol7
# 24              I-DATE      0.98   0.98     0.98     556  -fol7
# 25              I-DRUG      0.99   0.82     0.90      90  -fol7
# 26            I-FAMILY      1.00   1.00     1.00      34  -fol7
# 27              I-FREQ      0.97   0.94     0.96     233  -fol7
# 28     I-IMPLICIT_DATE      0.90   0.95     0.92     228  -fol7
# 29            I-METRIC      0.96   0.94     0.95     235  -fol7
# 30          I-MUTATION      0.94   0.84     0.89      19  -fol7
# 31   I-MUTATION_STATUS      0.94   0.98     0.96     145  -fol7
# 32   I-OCURRENCE_EVENT      0.91   0.79     0.85     250  -fol7
# 33          I-QUANTITY      0.66   0.85     0.74      59  -fol7
# 34     I-SMOKER_STATUS      0.97   1.00     0.98      31  -fol7
# 35             I-STAGE      0.99   0.98     0.98     158  -fol7
# 36           I-SURGERY      0.88   0.88     0.88     145  -fol7
# 37               I-TNM      0.91   0.90     0.91     164  -fol7
# 38                   O      0.98   0.98     0.98   28526  -fol7

# %% [markdown]
# ### se almacena el resultado del modelo

# %%
output1 = open('prime_data_' + MODEL + '.pkl', 'wb')
pickle.dump(prime_data_fold, output1)
output1.close()

output2 = open('total_data_' + MODEL + '.pkl', 'wb')
pickle.dump(total_data_fold, output2)
output2.close()

# %% [markdown]
# ## # Ejemplos

# %%
NER_samples = [
    "Paciente diagnosticado con cáncer de pulmón en marzo de 2019. ".split(),
    "No clínica urinaria ni respiratoria aguda .".split(),
    "Niega HTA, DM y DM .".split(),
    "No se observan signos de insuficiencia cardíaca .".split(),
    "Paciente tratado con 3 ciclos de de carboplatino .".split()
    
]



print("Examples: \n", NER_samples)
# Out:
# Examples:
#  [['Paciente', 'diagnosticado', 'con', 'cáncer', 'de', 'pulmón', 'en', 'marzo', 'de', '2019.'], ['No', 'clínica', 'urinaria', 'ni', 'respiratoria', 'aguda', '.'], ['Niega', 'HTA,', 'DM', 'y', 'DM', '.'], ['No', 'se', 'observan', 'signos', 'de', 'insuficiencia', 'cardíaca', '.'], ['Paciente', 'tratado', 'con', '3', 'ciclos', 'de', 'de', 'carboplatino', '.']]

# %% [markdown]
# ### Convertimos las Entradas del modelo

# %%
NER_samples_X    = []

for s1 in NER_samples:
    s1_int = []
    for w in s1:
        try:
            s1_int.append(word2idx[w.lower()])
        except KeyError:
            s1_int.append(word2idx['-OOV-'])
    NER_samples_X.append(s1_int)

NER_samples_X = pad_sequences(NER_samples_X, maxlen=LEN_SENTS, padding='post')




print("Examples: \n", NER_samples_X)
# Out:
# Examples:
#  [[ 4864  2832  6213 ...     0     0     0]
#  [12461  1118  4199 ...     0     0     0]
#  [11897     1     1 ...     0     0     0]
#  [12461  6947   375 ...     0     0     0]
#  [ 4864 13694  6213 ...     0     0     0]]

# %% [markdown]
# ### Se ejecuta la predición con la entrada de ejemplo en el modelo entrenado

# %%
predictions1 = model.predict(NER_samples_X)
print("NER: \n", predictions1, predictions1.shape)
# Out:
# /home/ambientes/python3.8/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:390: UserWarning: CRF Decoding does not work with KerasTensors in TF2.4. The bug has since been fixed in tensorflow/tensorflow##45534
#   return py_builtins.overload_of(f)(*args)
# NER:
#  [[35 31 35 ...  0  0  0]
#  [35 35 35 ...  0  0  0]
#  [35 35 35 ...  0  0  0]
#  [35 35 35 ...  0  0  0]
#  [35 31 35 ...  0  0  0]] (5, 306)

# %% [markdown]
# ### Conversión de la salida del modelo a un lista de indices de tags

# %%
log_tokens1 = logits_to_tokens(predictions1, idx2tag)


print("NER: \n", log_tokens1[0])
# Out:
# NER:
#  ['O', 'B-OCURRENCE_EVENT', 'O', 'B-CANCER_CONCEPT', 'I-CANCER_CONCEPT', 'I-CANCER_CONCEPT', 'O', 'B-DATE', 'I-DATE', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-', '-PAD-']

# %% [markdown]
# ## Resultado de NER:

# %%
for h, oracc in enumerate(NER_samples):
    heads = oracc
    body  = [log_tokens1[h][:len(oracc)]]
    display(HTML("<div style='overflow-x: auto; white-space: nowrap;'>" + 
                 tabulate(body, headers=heads, tablefmt="html") + 
                 "</div>"))
# Out:
# <div style='overflow-x: auto; white-space: nowrap;'><table>
# <thead>
# <tr><th>Paciente  </th><th>diagnosticado    </th><th>con  </th><th>cáncer          </th><th>de              </th><th>pulmón          </th><th>en  </th><th>marzo  </th><th>de    </th><th>2019.  </th></tr>
# </thead>
# <tbody>
# <tr><td>O         </td><td>B-OCURRENCE_EVENT</td><td>O    </td><td>B-CANCER_CONCEPT</td><td>I-CANCER_CONCEPT</td><td>I-CANCER_CONCEPT</td><td>O   </td><td>B-DATE </td><td>I-DATE</td><td>-PAD-  </td></tr>
# </tbody>
# </table></div>
# <div style='overflow-x: auto; white-space: nowrap;'><table>
# <thead>
# <tr><th>No  </th><th>clínica  </th><th>urinaria  </th><th>ni  </th><th>respiratoria  </th><th>aguda  </th><th>.  </th></tr>
# </thead>
# <tbody>
# <tr><td>O   </td><td>O        </td><td>O         </td><td>O   </td><td>O             </td><td>O      </td><td>O  </td></tr>
# </tbody>
# </table></div>
# <div style='overflow-x: auto; white-space: nowrap;'><table>
# <thead>
# <tr><th>Niega  </th><th>HTA,  </th><th>DM  </th><th>y  </th><th>DM  </th><th>.  </th></tr>
# </thead>
# <tbody>
# <tr><td>O      </td><td>O     </td><td>O   </td><td>O  </td><td>O   </td><td>O  </td></tr>
# </tbody>
# </table></div>
# <div style='overflow-x: auto; white-space: nowrap;'><table>
# <thead>
# <tr><th>No  </th><th>se  </th><th>observan  </th><th>signos  </th><th>de  </th><th>insuficiencia  </th><th>cardíaca     </th><th>.  </th></tr>
# </thead>
# <tbody>
# <tr><td>O   </td><td>O   </td><td>O         </td><td>O       </td><td>O   </td><td>B-COMORBIDITY  </td><td>I-COMORBIDITY</td><td>O  </td></tr>
# </tbody>
# </table></div>
# <div style='overflow-x: auto; white-space: nowrap;'><table>
# <thead>
# <tr><th>Paciente  </th><th>tratado          </th><th>con  </th><th>3         </th><th>ciclos  </th><th>de  </th><th>de  </th><th>carboplatino  </th><th>.  </th></tr>
# </thead>
# <tbody>
# <tr><td>O         </td><td>B-OCURRENCE_EVENT</td><td>O    </td><td>B-QUANTITY</td><td>B-METRIC</td><td>O   </td><td>O   </td><td>B-DRUG        </td><td>O  </td></tr>
# </tbody>
# </table></div>
